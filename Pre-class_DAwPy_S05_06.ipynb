# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(101)
df = pd.DataFrame(np.random.randint(9, size=(5, 4)), 
                  index = 'A B C D E'.split(), 
                  columns = 'W X Y Z'.split())

df
# Out:
#    W  X  Y  Z
# A  1  6  7  8
# B  4  8  5  0
# C  5  8  1  3
# D  8  3  3  2
# E  8  3  7  0

# %%
df.reset_index()
# Out:
#   index  W  X  Y  Z
# 0     A  1  6  7  8
# 1     B  4  8  5  0
# 2     C  5  8  1  3
# 3     D  8  3  3  2
# 4     E  8  3  7  0

# %%
df
# Out:
#    W  X  Y  Z
# A  1  6  7  8
# B  4  8  5  0
# C  5  8  1  3
# D  8  3  3  2
# E  8  3  7  0

# %%
newindx='CA NY WY OR CO'. split()
newindx
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['new_column'] = newindx

# %%
df
# Out:
#    W  X  Y  Z new_column
# A  1  6  7  8         CA
# B  4  8  5  0         NY
# C  5  8  1  3         WY
# D  8  3  3  2         OR
# E  8  3  7  0         CO

# %%
df.set_index("new_column")
# Out:
#             W  X  Y  Z
# new_column
# CA          1  6  7  8
# NY          4  8  5  0
# WY          5  8  1  3
# OR          8  3  3  2
# CO          8  3  7  0

# %%
df.set_index("Z")
# Out:
#    W  X  Y new_column
# Z
# 8  1  6  7         CA
# 0  4  8  5         NY
# 3  5  8  1         WY
# 2  8  3  3         OR
# 0  8  3  7         CO

# %%
df
# Out:
#    W  X  Y  Z newidx
# A  1  6  7  8     CA
# B  4  8  5  0     NY
# C  5  8  1  3     WY
# D  8  3  3  2     OR
# E  8  3  7  0     CO

# %%
df["X"]
# Out:
# A    6
# B    8
# C    8
# D    3
# E    3
# Name: X, dtype: int64

# %%
df.X
# Out:
# A    6
# B    8
# C    8
# D    3
# E    3
# Name: X, dtype: int64

# %%
df.new_column
# Out:
# A    CA
# B    NY
# C    WY
# D    OR
# E    CO
# Name: new_column, dtype: object

# %%
df[["X", "Y"]]
# Out:
#    X  Y
# A  6  7
# B  8  5
# C  8  1
# D  3  3
# E  3  7

# %%
df
# Out:
#    W  X  Y  Z new_column
# A  1  6  7  8         CA
# B  4  8  5  0         NY
# C  5  8  1  3         WY
# D  8  3  3  2         OR
# E  8  3  7  0         CO

# %%
df.loc["B", "W"]
# Out:
# 4

# %%
df.iloc[1, 0]
# Out:
# 4

# %%
df.Y
# Out:
# A    7
# B    5
# C    1
# D    3
# E    7
# Name: Y, dtype: int64

# %%
df.Y < 6
# Out:
# A    False
# B     True
# C     True
# D     True
# E    False
# Name: Y, dtype: bool

# %%
df[df.Y < 6]
# Out:
#    W  X  Y  Z new_column
# B  4  8  5  0         NY
# C  5  8  1  3         WY
# D  8  3  3  2         OR

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
hier_index
# Out:
# MultiIndex([('A1', 1),
#             ('A1', 2),
#             ('A1', 3),
#             ('A2', 1),
#             ('A2', 2),
#             ('A2', 3)],
#            )

# %%
data.loc["A1"]
# Out:
#           X         Y
# 1  2.706850  0.628133
# 2  0.907969  0.503826
# 3  0.651118 -0.319318

# %%
data.loc["A1", "X"]
# Out:
# 1    2.706850
# 2    0.907969
# 3    0.651118
# Name: X, dtype: float64

# %%
data.loc["A1", 1]
# Out:
# X    2.706850
# Y    0.628133
# Name: (A1, 1), dtype: float64

# %%
data.loc[("A1", 1), "X"]
# Out:
# 2.706849839399938

# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.sepal_width.value_counts()
# Out:
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.6     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: sepal_width, dtype: int64

# %%
df.sepal_width.sum()
# Out:
# 458.6

# %%
df.sepal_width.mean()
# Out:
# 3.057333333333334

# %%
df.sepal_width.unique()
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 2.9, 3.7, 4. , 4.4, 3.8, 3.3,
#        4.1, 4.2, 2.3, 2.8, 2.4, 2.7, 2. , 2.2, 2.5, 2.6])

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df[df.sepal_width.isnull()]
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
df[df.sepal_width < 2.3]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 60            5.0          2.0           3.5          1.0  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 119           6.0          2.2           5.0          1.5   virginica

# %%
df[60:61]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 60           5.0          2.0           3.5          1.0  versicolor

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.drop('sepal_length', axis=1)
# Out:
#      sepal_width  petal_length  petal_width    species
# 0            3.5           1.4          0.2     setosa
# 1            3.0           1.4          0.2     setosa
# 2            3.2           1.3          0.2     setosa
# 3            3.1           1.5          0.2     setosa
# 4            3.6           1.4          0.2     setosa
# ..           ...           ...          ...        ...
# 145          3.0           5.2          2.3  virginica
# 146          2.5           5.0          1.9  virginica
# 147          3.0           5.2          2.0  virginica
# 148          3.4           5.4          2.3  virginica
# 149          3.0           5.1          1.8  virginica
#
# [150 rows x 4 columns]

# %%
df.drop('sepal_length', axis=1)
# Out:
#      sepal_width  petal_length  petal_width    species
# 0            3.5           1.4          0.2     setosa
# 1            3.0           1.4          0.2     setosa
# 2            3.2           1.3          0.2     setosa
# 3            3.1           1.5          0.2     setosa
# 4            3.6           1.4          0.2     setosa
# ..           ...           ...          ...        ...
# 145          3.0           5.2          2.3  virginica
# 146          2.5           5.0          1.9  virginica
# 147          3.0           5.2          2.0  virginica
# 148          3.4           5.4          2.3  virginica
# 149          3.0           5.1          1.8  virginica
#
# [150 rows x 4 columns]

# %%
df.drop(1, axis=0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
df[df.sepal_width < 2.3]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 60            5.0          2.0           3.5          1.0  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 119           6.0          2.2           5.0          1.5   virginica

# %%
df.loc[df.sepal_width < 2.3]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 60            5.0          2.0           3.5          1.0  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 119           6.0          2.2           5.0          1.5   virginica

# %%
df_new = df.drop(df[df.sepal_width < 2.3].index)

# %%
df_new
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [146 rows x 5 columns]

# %% [markdown]
# # SESSION 6 - Pre-Class

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
df = sns.load_dataset("planets")
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.groupby('method')[['distance']].sum()
# Out:
#                                 distance
# method
# Astrometry                         35.75
# Eclipse Timing Variations        1261.44
# Imaging                          2166.91
# Microlensing                    41440.00
# Orbital Brightness Modulation    2360.00
# Pulsar Timing                    1200.00
# Pulsation Timing Variations         0.00
# Radial Velocity                 27348.11
# Transit                        134242.77
# Transit Timing Variations        3313.00

# %%
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.groupby('method').agg(["count", "max", "min", "mean", "std"])
# Out:
#                               number                              \
#                                count max min      mean       std
# method
# Astrometry                         2   1   1  1.000000  0.000000
# Eclipse Timing Variations          9   2   1  1.666667  0.500000
# Imaging                           38   4   1  1.315789  0.933035
# Microlensing                      23   2   1  1.173913  0.387553
# Orbital Brightness Modulation      3   2   1  1.666667  0.577350
# Pulsar Timing                      5   3   1  2.200000  1.095445
# Pulsation Timing Variations        1   1   1  1.000000       NaN
# Radial Velocity                  553   6   1  1.721519  1.157141
# Transit                          397   7   1  1.954660  1.399119
# Transit Timing Variations          4   3   2  2.250000  0.500000
#
#                               orbital_period                              \
#                                        count            max          min
# method
# ...

# %%
df.groupby('method').

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [np.nan, np.nan, np.nan]],
                 columns=['A', 'B', 'C'])

# %%
df.transform(lambda x: x+1)
# Out:
#      A    B     C
# 0  2.0  3.0   4.0
# 1  5.0  6.0   7.0
# 2  8.0  9.0  10.0
# 3  NaN  NaN   NaN
